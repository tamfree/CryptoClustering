# %%
# Import required libraries and dependencies
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
market_data_df = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
market_data_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
market_data_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
market_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, bitcoin to digibyte
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   price_change_percentage_24h   41 non-null     float64
#  1   price_change_percentage_7d    41 non-null     float64
#  2   price_change_percentage_14d   41 non-null     float64
#  3   price_change_percentage_30d   41 non-null     float64
#  4   price_change_percentage_60d   41 non-null     float64
#  5   price_change_percentage_200d  41 non-null     float64
#  6   price_change_percentage_1y    41 non-null     float64
# dtypes: float64(7)
# memory usage: 2.6+ KB

# %%
market_data_df.shape
# Out:
# (41, 7)

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
market_data_normalized_arr = StandardScaler().fit_transform(market_data_df)
market_data_normalized_arr
# Out:
# array([[ 5.08529366e-01,  4.93193071e-01,  7.72200433e-01,
#          2.35459633e-01, -6.74950963e-02, -3.55953481e-01,
#         -2.51636882e-01],
#        [ 1.85445894e-01,  9.34445040e-01,  5.58692121e-01,
#         -5.43409317e-02, -2.73482725e-01, -1.15759474e-01,
#         -1.99352110e-01],
#        [ 2.17739616e-02, -7.06336853e-01, -2.16804207e-02,
#         -6.10301536e-02,  8.00452481e-03, -5.50246924e-01,
#         -2.82060506e-01],
#        [-4.07643829e-02, -8.10928066e-01,  2.49457974e-01,
#         -5.03879651e-02, -3.73164019e-01, -4.58258816e-01,
#         -2.95546142e-01],
#        [ 1.19303608e+00,  2.00095907e+00,  1.76061001e+00,
#          5.45842065e-01, -2.91202870e-01, -4.99847761e-01,
#         -2.70316950e-01],
#        [ 8.91870708e-01,  1.32729453e+00,  8.00214184e-01,
#         -5.71478992e-02,  7.78653106e-01, -1.88231917e-01,
#         -2.25532605e-01],
#        [ 1.13972400e-02,  2.57225091e+00,  1.10164693e+00,
# ...

# %%
#CONSTANTS
COIN_ID_COL = "coin_id"

# %%
# Create a DataFrame with the scaled data
scaled_market_data_df = pd.DataFrame(market_data_normalized_arr, columns=market_data_df.columns)

# Copy the crypto names from the original data
scaled_market_data_df[COIN_ID_COL] = market_data_df.index

# Set the coinid column as index
scaled_market_data_df = scaled_market_data_df.set_index(COIN_ID_COL)

# Display sample data
scaled_market_data_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
def getKMeans_ElbowDataDF(in_dataframe):
    # Create a list with the number of k-values to try
    # Use a range from 1 to 11
    clusters = range(1, 11)

    # Create an empty list to store the inertia values
    inertia = []

    # Create a for loop to compute the inertia with each possible value of k
    # Inside the loop:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    # 2. Fit the model to the data using the scaled DataFrame
    # 3. Append the model.inertia_ to the inertia list
    for k in clusters:
        model = KMeans(k, n_init="auto", random_state=1)
        model.fit(in_dataframe)
        inertia.append(model.inertia_)

    # Create a dictionary with the data to plot the Elbow curve
    elbow_data = {"k": clusters,
                  "inertia": inertia}

    # Create a DataFrame with the data to plot the Elbow curve
    return pd.DataFrame(elbow_data)

# %%
# Display the DataFrame
elbow_df = getKMeans_ElbowDataDF(scaled_market_data_df)
elbow_df
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  212.123342
# 2   3  165.136752
# 3   4   79.022435
# 4   5   66.413051
# 5   6   61.634088
# 6   7   46.074467
# 7   8   43.392694
# 8   9   32.913223
# 9  10   30.469111

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_df.plot(x="k", y="inertia")
# Out:
# <Axes: xlabel='k'>

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer:** 4 maybe 5

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k
k = 4
orig_data_KM_model = KMeans(k, n_init="auto", random_state=1)

# %%
# Fit the K-Means model using the scaled data
orig_data_KM_model.fit(scaled_market_data_df)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
crypto_cluster_predicitions_arr = orig_data_KM_model.predict(scaled_market_data_df)

# View the resulting array of cluster values.
crypto_cluster_predicitions_arr
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame
scaled_market_data_df2 = scaled_market_data_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
scaled_market_data_df2["cluster_predictions"] = crypto_cluster_predicitions_arr

# Display sample data
scaled_market_data_df2
# Out:
#                       price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                                  0.508529                    0.493193
# ethereum                                 0.185446                    0.934445
# tether                                   0.021774                   -0.706337
# ripple                                  -0.040764                   -0.810928
# bitcoin-cash                             1.193036                    2.000959
# binancecoin                              0.891871                    1.327295
# chainlink                                0.011397                    2.572251
# cardano                                  0.102530                    1.508001
# litecoin                                 0.077497                    0.334297
# bitcoin-cash-sv                          0.448952                   -0.190684
# crypto-com-chain                         0.331280                   -1.614844
# ...

# %%
# Create a scatter plot using Pandas plot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.
scaled_market_data_df2.plot.scatter(x="price_change_percentage_24h", y="price_change_percentage_7d", c="cluster_predictions", colormap = "rainbow")
# Out:
# <Axes: xlabel='price_change_percentage_24h', ylabel='price_change_percentage_7d'>

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the original scaled DataFrame to reduce to three principal components.
crypto_pca = pca.fit_transform(scaled_market_data_df)

# View the first five rows of the DataFrame. 
crypto_pca[:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information  can be attributed to each principal component.
variance_ratio = pca.explained_variance_ratio_
variance_ratio
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**

# %%
sum(variance_ratio)
# Out:
# 0.8950316570309842

# %%
crypto_pca_df = pd.DataFrame(crypto_pca, columns=['PCA1', 'PCA2', 'PCA3'], )
crypto_pca_df
# Out:
#         PCA1      PCA2      PCA3
# 0  -0.600667  0.842760  0.461595
# 1  -0.458261  0.458466  0.952877
# 2  -0.433070 -0.168126 -0.641752
# 3  -0.471835 -0.222660 -0.479053
# 4  -1.157800  2.041209  1.859715
# 5  -0.516534  1.388377  0.804071
# 6  -0.450711  0.517699  2.846143
# 7  -0.345600  0.729439  1.478013
# 8  -0.649468  0.432165  0.600303
# 9  -0.759014 -0.201200 -0.217653
# 10 -0.248198 -1.376252 -1.462026
# 11 -0.438408 -0.175337 -0.663388
# 12 -0.693425 -0.473815 -0.527597
# 13  0.060499  2.909404  1.498571
# 14 -0.393352 -0.108192 -0.012756
# 15 -0.796176 -0.494409  1.082812
# 16  0.064075 -1.269825 -1.098829
# 17 -0.489015 -0.732719 -0.062543
# 18 -0.306272  0.703415  1.714224
# 19 -0.513528 -0.142802 -0.656566
# 20 -0.362120 -0.986914 -0.728752
# 21 -0.604265  0.827398  0.439316
# 22 -0.413296 -0.674115 -1.076628
# 23 -0.407483 -0.212507 -0.351426
# 24  0.608974  0.563532 -1.148742
# 25 -0.450211 -0.151019 -0.647401
# 26 -0.764665 -0.517886  0.204990
# ...

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you

# Creating a DataFrame with the PCA data
crypto_pca_df = pd.DataFrame(crypto_pca, columns=['PCA1', 'PCA2', 'PCA3'])

# Copy the crypto names from the original data
crypto_pca_df[COIN_ID_COL] = scaled_market_data_df.index

# Set the coinid column as index
crypto_pca_df = crypto_pca_df.set_index(COIN_ID_COL)

# Display sample data
crypto_pca_df
# Out:
#                           PCA1      PCA2      PCA3
# coin_id
# bitcoin              -0.600667  0.842760  0.461595
# ethereum             -0.458261  0.458466  0.952877
# tether               -0.433070 -0.168126 -0.641752
# ripple               -0.471835 -0.222660 -0.479053
# bitcoin-cash         -1.157800  2.041209  1.859715
# binancecoin          -0.516534  1.388377  0.804071
# chainlink            -0.450711  0.517699  2.846143
# cardano              -0.345600  0.729439  1.478013
# litecoin             -0.649468  0.432165  0.600303
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653
# crypto-com-chain     -0.248198 -1.376252 -1.462026
# usd-coin             -0.438408 -0.175337 -0.663388
# eos                  -0.693425 -0.473815 -0.527597
# monero                0.060499  2.909404  1.498571
# tron                 -0.393352 -0.108192 -0.012756
# tezos                -0.796176 -0.494409  1.082812
# okb                   0.064075 -1.269825 -1.098829
# ...

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11


# Create an empty list to store the inertia values


# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using PCA DataFrame.
# 3. Append the model.inertia_ to the inertia list


# Create a dictionary with the data to plot the Elbow curve


# Create a DataFrame with the data to plot the Elbow curve


# Display the DataFrame
pca_elbow_data = getKMeans_ElbowDataDF(crypto_pca_df)
pca_elbow_data
# Out:
#     k     inertia
# 0   1  256.874086
# 1   2  182.339530
# 2   3  135.442408
# 3   4   49.665497
# 4   5   38.672582
# 5   6   34.507577
# 6   7   23.728365
# 7   8   18.574523
# 8   9   15.572672
# 9  10   11.407667

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
pca_elbow_data.plot(x="k", y="inertia")
# Out:
# <Axes: xlabel='k'>

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** If 4 is selected instead of 5, no.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
kmean_withPCA_model = KMeans(n_clusters=4,n_init="auto", random_state=1)

# %%
# Fit the K-Means model using the PCA data
kmean_withPCA_model.fit(crypto_pca_df)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
crypto_predictions_using_PCA = kmean_withPCA_model.predict(crypto_pca_df)

# Print the resulting array of cluster values.
print(crypto_predictions_using_PCA)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 3 2 0 0 1
#  0 0 0 0]

# %%
# Create a copy of the DataFrame with the PCA data
crypto_pca_df2 = crypto_pca_df.copy()

# Add a new column to the DataFrame with the predicted clusters
crypto_pca_df2["cluster_predictions"] = crypto_predictions_using_PCA

# Display sample data
crypto_pca_df2.head()
# Out:
#                   PCA1      PCA2      PCA3  cluster_predictions
# coin_id
# bitcoin      -0.600667  0.842760  0.461595                    2
# ethereum     -0.458261  0.458466  0.952877                    2
# tether       -0.433070 -0.168126 -0.641752                    0
# ripple       -0.471835 -0.222660 -0.479053                    0
# bitcoin-cash -1.157800  2.041209  1.859715                    2

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`. 
crypto_pca_df2.plot.scatter(x="PCA1", y="PCA2", c="cluster_predictions", colormap = "rainbow")
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index.
pca_component_weights = pd.DataFrame(pca.components_.T, columns=["PCA1", "PCA2", "PCA3"], index=scaled_market_data_df.columns)
pca_component_weights
# Out:
#                                   PCA1      PCA2      PCA3
# price_change_percentage_24h  -0.416728  0.358162 -0.218795
# price_change_percentage_7d   -0.102432  0.227432  0.787670
# price_change_percentage_14d  -0.009162  0.540415  0.349534
# price_change_percentage_30d   0.191523  0.562182 -0.181744
# price_change_percentage_60d   0.320365  0.434040 -0.361377
# price_change_percentage_200d  0.594468  0.027735  0.039733
# price_change_percentage_1y    0.568379 -0.150789  0.210541

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:**

# %% [markdown]
# | Influence  | PCA1 | PCA2 | PC3 |
# | -- | --- | ---- | ---- |
# | Strongest Positive | price_change_percentage_200d | price_change_percentage_30d | price_change_percentage_7d |
# | Strongest Negative | price_change_percentage_24h | price_change_percentage_1y | price_change_percentage_60d |
